# %% [markdown]
# # PyBay Pre-Conference Workshop: Crash Course in Computer Science
#
# NB: We will not be covering everything or else we will be here forever.
#
# - Computer architecture
# - Binary representation (what does it really look like under the hood)
# - Very interactive, very exercise-based
#     - Go to [here](https://github.com/Bradfield/pybay2017) for the exercises.
#
# ## best way to learn computer science is to practice ##
# - Computer science is like learning French or playing tennis. Until you do the exercise, you
#
# ## What is a computer capable of storing? ##
# A computer can store "bits" (on or off). From sequences of bits and an interpretation, we somehow model data.
# NB: A byte can be considered a location in memory. 8 bits = 1 byte (da controllare)
# - Why 8 bits? 7 bits is adequate for ASCII.
#
# Octet = 8 bits
#
# Byte = smallest unit for addressable RAM
#
# 1 byte can store 2^8
#
# How many colors?
# rgb(256, 256, 256)--> three bytes of storage, 256
#
# ## On 32-bit machine, how much RAM can you have? ##
# What does it meant to have a 32-bit machine? Each register (small piece of RAM) has 32-bit long address (number of bytes, 2^32, 4 billion bites). DA CONTROLLARE
#
# Why did we move to 64 bits? More RAM
#
# Sidenote: Look at IPv6 and how long IP addresses are (IP addresses were originally 4 bytes, 2^32 = (2^8)^4)
#
#
# ## Bitmap Conversion
# Task: Convert Bitmap Image to Greyscale
#
# NB: Cloned Github from
#
# Things to know:
# - Where does the header end and the data begins?
# - Greyscale = average of the three rgb values then take those bytes and re-write them
# - Review offset in hex and bitmap
#
# Hexdump is visualization of data. The left is the row number/location in data, the right is ASCII
#
# ## Data Structures
#
# ### Queue vs Stack: Dealing with Sequence of Data
# **Queue**
# - First In, First Out (like a line in real-life)
# **Stack**
# - Last In, First Out
#
# How do we model a queue in Python?
# - A list with insert(0) and push() OR append() and pop(0)
#
# **Why can't we just put integers in?**
# Something about a pointer, a list comes pre-fabricated with a set number of pointers
# Items beyond that set number will force a new list to be created
#
# Does adding item to a list vary depending on length on list? Constant versus linear-time operation?
# - It's really linear (adding requires you know an index and going to the last pointer)
# - Amortized time: we assume constant time operation when it really isn't because most of time we're okay.
#
# *Key Takeaway: "The most important thing you can do as a Python programmer is learn C. If you don't want to learn C, speak to me after,and I'll convince you to learn C."*
#
# What about popping or removing a list? Constant or linear?
# - Constant time again
# - If you pop from beginning and add at the end at same time, you have to perform a shift (in fact), the FIFO operation is a shift operation.
#
# If a list gets too big, we run into a problem:
# - **Stack** vs **Heap** (DA CONTROLLARE)
# - If we have a python program, what does OS do to run it?
#     1. Allocate RAM to run it? (CPython)
#     2. Allocate RAM for the stuff in the code (variables and stuff)
#     3. Allocate some amount of RAM for stuff running
#             a) STACK = notionally structure
#                 - function calls
#                 - local variables
#             b) HEAP = unstructure space
# - Python and STACK/HEAP
#     -No stack overflow in Python? It goes into the heap-->If heap used up, it creates a problem
# - So if a list is too big, you run into a big problem.
#
# Other Considerations
# - List and nodes? Lists run out of RAM at some point?
# - Rebuffer? Finite amount of space can be used as queue (when you reach end of top value, begin again at a time and read next, problem: write over old data, but block reader from overtaking writer, and writer from overtaking reader)
#
#
# Fun Fact: NumPy is written in C.
#
#
# ## Why is Python slow?
#
# Python has to compile and interpret (pyc).
#
# L1 Cache
#
# Memory Hierarchy
#
# Python program getting slow means that you are going to RAM too much.
#
# In the 60s, we did not care about RAM access space because our CPU's were so slow. Nowadays, we can do a billion operations per second.
# - Moore's Law (doubling of computational power, every 12 months/16 mounths)
#
# Thus, RAM access has not changed that much. Relative cost of doing an instruction vs accessing RAM has grown.
#
# How long does it take to execute one operation on a gigahertz machine?
# Answer: Like a billionth of a second?
#
# How long does it take to access RAM?
# Answer: Like two hundred nanoseconds. So... a bit more time; RAM is slower.
#
# Consider a program where we are getting an average of stuff in a list.... how much time is spent calculating and how much time is spent retrieving?
#
# CPU Cache resolves part of this problem (CPU performance versus RAM performance)
# - Piece of Faster RAM closer to CPU, idea being when you go to RAM, get not just the item requested, but the other stuff in the neighborhood (cacheline)
# - Memory hierarchy idea
# - NB: Even SSD is still very slow. Hard-drive is rather slow.
# - Cache-line is about 64 bytes. It's reasonable.
#
# The people who do NumPy and whatnot think about these things often.
#
# What is the cost of sending large amounts of data?
# - Latency to New York: trying to send one packet to NY? Half speed of light-ish?, like 35 or so milliseconds
# - What is the throughput though?
# - Snowball (DA CONTROLLARE) Oh, God... It's [terrifying](http://docs.aws.amazon.com/snowball/latest/ug/whatissnowball.html).
#     -they have a thing called a snowmobile (it's a truck with a trailer full of storage)
# - Sneaker rate = getting it there but on your vote
# - What does it mean when a machine has multie core?
#     - A core is an independent CPU that allows you to do stuff concurrently, like parallel.
#     - Concurrency vs. parallelism?
#         - Concurrency = illusion of parellism, that things are running at the same time.
#     - Virtual core? Hyper threading?
#     - Virtual core compete with real core for requests?
#
# What is one cycle?
# - Vibrating piece of quartz in computer?
#
# SRAM = very fast but expensive (registers)
#
# DRAM = main ram, much cheaper but slower
#
# See diagrams for this, L1, L2, L3
#
#
# These days, all CPU caches are implemented in SRAM.
#
# If you can model something more compactly (space), there are fewer cache lines (time).
# Using less RAM is a way to make things faster.
# If you are db manager system or writing a game, this is important.
# - "If you drop a few frames in VR, does anyone know what happens? You get sick." If you can't work with cache lines.
#
# Why is stuff so slow on web or allowed to be slow?
# - Latency has been an entrenched problem (however, now we're catching up)
# - However, although things are better, we still write slow code.
#
#
# Interplay between RAM and CPU, cachelines and memory usage, are big issues.
#
# Python in its very nature not very efficient resource-wise.
#
# If something is around for n years, it'll be around for another n years.
#
# German Tank Problems
#
#
# With Queue exercise, the types we use even at a high levels are limited.
# - Big O thoughts: When something is Big O(1)==something is constant with respect to size of input (it'll always be 10 seconds despite large input).
#
#
# If we want all shake hands, how would you code the algorithm to do this?
# For each person in the line they shake hands, with each subsequent person
#
# What's worse than O(n^2)? Anything that is basically natural growth-ish. (2^n)
#
# ## Dictionaries
# JS has object-type which is similar.
# Go does not have true dictionaries.
#
# How do we make a key-value storage without dictionaries? Let's say dictionaries ceased to exist.
# - List of tuples
#
# Binary Tree:
# - A Node that points two more nodes (linked lists)
#
# What we underlie with the hash or the address?
# - A continuous implementation in memory?
# - Allocated in memory
# - Store equivalent of key-value
# - Hash functions (high entropy) DA IMPARARE e DA CONTROLLARE
#
#
# This talk really needed pictures.
#
#
# How do computer networks do checksums very fast?
# - Bitwise operations
# - Take every bytes in the packet and XOR against next set of bytes. Or something like that
#     -If A is TRue but B is false, XOR = true
#     -If both false, XOR = false
#     - If we used OR, we get all 1's.
#     - If we used AND, we get all 0's (some distortion, something lost)
# - We can model electronic circuits with Boolean algebra ([Claude Shannon](https://en.wikipedia.org/wiki/Claude_Shannon)'s big idea)
#
# Ruby moved from chaining to open addressing
# - Lots of collisions (collisions = checksums are the same, oops)

# %%
mark = [1, 23, 2]

# %%
mark[0]
# Out:
# 1

# %%
mark
# Out:
# [1, 4, 2]

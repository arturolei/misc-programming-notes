# %% [markdown]
# # Anatomy of edX, Nate Aune
#
# edX is a MOOC-focused brand.
# - Over 1500 courses available, many focused on computer science-related topics
# - Over 30 top universities (you can take more or less the same courses)
#
# Open edX = web-based platform for creating, tracking online courses at a massive scale
# - APGL (Open Source) license
#
# FIrst MOOC created in 2012 (March)
# Janury 2013: 20 moocs, 500k learners
#
# Who is adopting Open edX?
# - "Come for the code, stay for the community."
# - Growth is linear since 2015
# - Today, according to the tracking data, there are about 5000+ courses or 800+ sites
#
#
# Mission of edX: provide high quality education for everyone, everywhere.
#
# Other countries are using the edX platform to educate their workcourses (at scale, at much lower cost)
#
# Simply to the Python pip/pep process, Open edX has adopted something similar.
#
# Top Contributions for Open edX:
# - Stanford, Google, Credo, Microsoft
# - Big Picture: edX is growing.
#
# Open edX is made with both Python and other languages.
# 1.87 DJ's in edX
#
# Talk will examine the perspective from developer and implementer.
#
# There is a nifty visualization (codeswarm) that shows the evolution of the code over time.
# - "You are re-building the plane as you fly it."
#
# Queued using celery, rabbitmq (how they handle massive long-running processes)
#
# Open edX uses celery.
#
# How do you implement edX?
# - Network topology (how do the different components
#
#
# Very Small Deployments
# - Run from two machines
# - All apps on one machine
# - All databases on second machine.
#
# Elastic load balancer
#
# They use MySQL
#
# How to scale forum traffic?
# - edX and forums have to be scaled together
#
# You have to multiple contingencies ready.
#
# Hosting Costs to run Open edX in Production:
# - $950 to 1400 a month
#
# What is going behind the scenes?
#
# FOCUS: NGINX
#
# So much devops.
#
# Requesting static/dynamic assets gets different routers, gUnicorn (proxied to)
#
# The edX forums are a Sinatra app written in Ruby, created at UC Berkeley
#
# Ansibile script that shoots out jSon.
#
# What are the Python packages?
# - A lot.
# - The depedency tree is massive.
#
# As much as possible, edX has trying to keep thing as smooth as possible. Provisioning phase
#
# They use some tool to perform...
#
# Ansible (Python)
# Terraform
# - Provision servers and other resources.
# - Any configuration tool once it is created.
# - Tiers:
#     - Basic (single server)
#     - Pro
#     - Enterprise
#
# Create a directory for edx-terraform
# - see slide for directory structure.
#
# make plan-- terraform plank (a dry run that lets you see what happens when you run this thing for real)
#
# Ansible:
# - automoates software config and deployment
# - ORchestration controlled by a controlling machine
#
# Stateless playbook
#
# Run the playbook
# -ansible-playbook
#
# Docker (local dev environment)
# - A way to avoid terraform and ansible stuff
# - Docker Compose allows you to spin a multiple node thingy without the cost of creating servers on AWS
# - Not quite stable, look up devstack or vagrant
#
# Kite-matic
#
# "Demistying the Open edX Architecture"
#
# More info:
# - look at the codebase on edx-platform, see github
# - Slack community
#
# Is there sample code available?
#
# What about non-internet places (countries with slow internet)?
# - Hack Day Project: running Open edX without the internet? Is it possible without external dependencies?
#     - Can we fit it on a Rasberry Pi
#
# - Not a great answer, no real solution (downloading on mobile phones)
#
# Presentation will be made available online later.

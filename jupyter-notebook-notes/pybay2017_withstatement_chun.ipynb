# %% [markdown]
# # Get with it: gain the wherewithal to understand Python's with statement & context managers by Wesley Chun, 8/13/17
#
# Content of Talk:
# - Historical motivation
# - With Statement
# - Intro to Context managers
#
#
# Context:
# - There have been more than several ways of reading and opening files since the inception of Python.
#
#
# 2002:
# -universal newline support (PEP 278)
# - More iterators
#
# 2006:
# - Debut of with statement
# - ```python with open```
#
# 2008:
# - With statement fully integrated
#
# 2009:
# - newlines = None, Universal newline
#
# 2009-Present
# - Much clearer version
# - There's been a gradual form of things
#
# ```python with``` statement allows you to open and close without the close statement.
# - If you code in Python 2, you might want to import with open from the future.
#
# Before the with statement:
# - logic to allocate resource
# - suite
# - logic to release resource
#
# Problem here is that it adds additional complexicatiy.
#
#
# With the With Statement
# -Push most logic for both to context manger
#    - Simplify allocation
#    - Hide releasing of resource
#
#
# #### Context Management:
# - Context manager handles stuff you don't want to worry about as app developer
# - Start when you get it
# - Context manager handles logistics
#
# Context manager with files is farily easy.
#
# Locks even simpler
# - From
#     - lock.acquire()
#     - lock.release()
#  -To:
#      - With lock:
#
# With statement greatly simplifies code.
#
# #### Inital Context Managers:
# - file
# - decimal.Context
# - thread.LockType
# - threading.Loc
#
#
# #### Implementing Context Managers
# Old School:
# ```python
# url = 'http://python.org'
# u = urlib.urlopen(URL)
# print u.readline()
# u.close
# ```
# Goal:
# ```python
# with urllib.urlopen(URL)```

# %% [markdown]
# #### Context manager definition:
# - Class
# - __enter__ and __exit__
#
# References:
# documentation for cntextlib
# with-statement-context-managers
# pep-0343
# resource acquisition is initalization
#
#
# #### Conclusion
# - Context management simplifies plumbling code
# - allows developers to focus on applications
# - With statement is now usable not just for files.
#
#
# Addendum:
# OLD:
# with open
#     with open
#
# NEW:
# With x as f, open(x) as y:
